# %% [markdown]
# ***DATA MANIPULATION AND ANALYSIS USING PANDAS***

# %%
pip install pandas

# %%
#Importing of pandas library
import pandas as pd

# %% [markdown]
# Basic operations using pandas

# %%
#Creating a new DataFrame
df1 = pd.DataFrame({'A':[1,2,3,4],'B':['hello','how','are','you']})

# %%
df1
# Out:
#    A      B
# 0  1  hello
# 1  2    how
# 2  3    are
# 3  4    you

# %% [markdown]
# Data Frame is being created, where [ A,B ] are the names of columns

# %%
df1.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %% [markdown]
# *** Loading of the data ***

# %%
df = pd.read_csv("hp_data.csv")
df=df.rename(columns={'Unnamed: 0':'Id'})

# %% [markdown]
# *** Data Exploration ***

# %%
df.head()

#View top rows
# Out:
#      Id     price       place                 built  sqft    sale  yearsOld  \
# 0  1341   6300000  BTM Layout  Super built-up  Area  1450  Resale         5
# 1  2126  11500000   Yelahanka  Super built-up  Area  2190  Resale         5
# 2   816   3800000  Whitefield  Super built-up  Area  1019  Resale         1
# 3  2708  10500000  Ambalipura  Super built-up  Area  1857  Resale        15
# 4  1041  11500000   Yelahanka  Super built-up  Area  2190  Resale         5
#
#    floor  totalFloor  bhk
# 0      1           4    1
# 1      3           5    3
# 2      2           5    2
# 3      4           5    4
# 4      3           5    3

# %%
df.tail()

#View bottom rows
# Out:
#         Id    price                 place                 built  sqft    sale  \
# 3495   636  3800000            Whitefield  Super built-up  Area  1019  Resale
# 3496  1664  6300000            BTM Layout  Super built-up  Area  1450  Resale
# 3497  1252  7350000        Yelachenahalli  Super built-up  Area  1330  Resale
# 3498   903  4800000  Abbaiah Reddy Layout        Built-up  Area  1200  Resale
# 3499  2183  3800000            Whitefield  Super built-up  Area  1019  Resale
#
#       yearsOld  floor  totalFloor  bhk
# 3495         1      2           5    2
# 3496         5      1           4    1
# 3497        10      1           4    1
# 3498        10      1           4    1
# 3499         1      2           5    2

# %%
df.head(300)

#view first 300 rows
# Out:
#        Id     price                place                 built  sqft    sale  \
# 0    1341   6300000           BTM Layout  Super built-up  Area  1450  Resale
# 1    2126  11500000            Yelahanka  Super built-up  Area  2190  Resale
# 2     816   3800000           Whitefield  Super built-up  Area  1019  Resale
# 3    2708  10500000           Ambalipura  Super built-up  Area  1857  Resale
# 4    1041  11500000            Yelahanka  Super built-up  Area  2190  Resale
# ..    ...       ...                  ...                   ...   ...     ...
# 295  2568   7350000       Yelachenahalli  Super built-up  Area  1330  Resale
# 296  1262   7350000       Yelachenahalli  Super built-up  Area  1330  Resale
# 297  1585   7350000       Yelachenahalli  Super built-up  Area  1330  Resale
# 298  1605   7350000       Yelachenahalli  Super built-up  Area  1330  Resale
# 299  1243  15000000  Devarabeesana Halli  Super built-up  Area  1672  Resale
#
#      yearsOld  floor  totalFloor  bhk
# ...

# %%
df.describe()

#Statistics Summary
# Out:
#                 Id         price         sqft     yearsOld        floor  \
# count  3500.000000  3.500000e+03  3500.000000  3500.000000  3500.000000
# mean   1484.225714  8.067807e+06  1538.163143     7.602000     4.197714
# std     852.423418  4.984973e+06   416.264178     3.803196     4.782410
# min       0.000000  3.800000e+06  1019.000000     1.000000     1.000000
# 25%     737.750000  4.800000e+06  1200.000000     5.000000     1.000000
# 50%    1492.000000  6.600000e+06  1543.000000     5.000000     3.000000
# 75%    2218.250000  1.050000e+07  1784.000000    10.000000     4.000000
# max    2944.000000  4.750000e+07  4856.000000    15.000000    18.000000
#
#         totalFloor          bhk
# count  3500.000000  3500.000000
# mean      6.371429     4.197714
# std       4.461808     4.782410
# min       4.000000     1.000000
# 25%       4.000000     1.000000
# 50%       4.000000     3.000000
# 75%       5.000000     4.000000
# max      29.000000    18.000000

# %%
df.dtypes

#Kind of data present in each column
# Out:
# Id             int64
# price          int64
# place         object
# built         object
# sqft           int64
# sale          object
# yearsOld       int64
# floor          int64
# totalFloor     int64
# bhk            int64
# dtype: object

# %%
df.isnull().sum()

#Finding out the missing values count in each and every column
# Out:
# Id            0
# price         0
# place         0
# built         0
# sqft          0
# sale          0
# yearsOld      0
# floor         0
# totalFloor    0
# bhk           0
# dtype: int64

# %% [markdown]
# *** Data Selection ***

# %%
df['price']

#select a particular column --->>> df["name_of_column"]
# Out:
# 0        6300000
# 1       11500000
# 2        3800000
# 3       10500000
# 4       11500000
#           ...
# 3495     3800000
# 3496     6300000
# 3497     7350000
# 3498     4800000
# 3499     3800000
# Name: price, Length: 3500, dtype: int64

# %%
df[['price','sqft']]

#Select multiple columns --->>> df[["column_1","column_2"]]
# Out:
#          price  sqft
# 0      6300000  1450
# 1     11500000  2190
# 2      3800000  1019
# 3     10500000  1857
# 4     11500000  2190
# ...        ...   ...
# 3495   3800000  1019
# 3496   6300000  1450
# 3497   7350000  1330
# 3498   4800000  1200
# 3499   3800000  1019
#
# [3500 rows x 2 columns]

# %%
v = df[['price','sqft','bhk']]
v
# Out:
#          price  sqft  bhk
# 0      6300000  1450    1
# 1     11500000  2190    3
# 2      3800000  1019    2
# 3     10500000  1857    4
# 4     11500000  2190    3
# ...        ...   ...  ...
# 3495   3800000  1019    2
# 3496   6300000  1450    1
# 3497   7350000  1330    1
# 3498   4800000  1200    1
# 3499   3800000  1019    2
#
# [3500 rows x 3 columns]

# %%
type(v)
# Out:
# pandas.core.frame.DataFrame

# %%
df['price'][1:100:3]

#Selecting rows with the help of indexing --->>> df.iloc[start_index : End_index : Jump]
# Out:
# 1     11500000
# 4     11500000
# 7     15000000
# 10     3800000
# 13     4025000
# 16    10500000
# 19     7350000
# 22     4900000
# 25     4900000
# 28     4800000
# 31     4025000
# 34    11500000
# 37    10500000
# 40     4900000
# 43     4900000
# 46     7900000
# 49     7350000
# 52     7900000
# 55    15000000
# 58     7350000
# 61     6300000
# 64     4025000
# 67     4025000
# 70    11500000
# 73     7350000
# 76     7350000
# 79    11500000
# 82    11500000
# 85     4900000
# 88     7900000
# 91    15000000
# 94     4900000
# 97     4800000
# Name: price, dtype: int64

# %%
df[['price','sqft']][1:50:4]
# Out:
#        price  sqft
# 1   11500000  2190
# 5   15000000  1672
# 9    4900000  1100
# 13   4025000  1543
# 17   7900000  1784
# 21  10500000  1857
# 25   4900000  1100
# 29   6300000  1450
# 33   3800000  1019
# 37  10500000  1857
# 41  11500000  2190
# 45   4800000  1200
# 49   7350000  1330

# %%
df.columns

#view of all the columns present in the dataset
# Out:
# Index(['Id', 'price', 'place', 'built', 'sqft', 'sale', 'yearsOld', 'floor',
#        'totalFloor', 'bhk'],
#       dtype='object')

# %%
df.iloc[1:5]

#Here we are selecting rows with the help of indexing

# iloc [1:5] ---->> Start from index 1 and go till index 4 (exclude last index from condition same like of indexing in any coding language)
# Out:
#      Id     price       place                 built  sqft    sale  yearsOld  \
# 1  2126  11500000   Yelahanka  Super built-up  Area  2190  Resale         5
# 2   816   3800000  Whitefield  Super built-up  Area  1019  Resale         1
# 3  2708  10500000  Ambalipura  Super built-up  Area  1857  Resale        15
# 4  1041  11500000   Yelahanka  Super built-up  Area  2190  Resale         5
#
#    floor  totalFloor  bhk
# 1      3           5    3
# 2      2           5    2
# 3      4           5    4
# 4      3           5    3

# %%
df.iloc[0:5]

#start from 0th index and go till 4th index
# Out:
#      Id     price       place                 built  sqft    sale  yearsOld  \
# 0  1341   6300000  BTM Layout  Super built-up  Area  1450  Resale         5
# 1  2126  11500000   Yelahanka  Super built-up  Area  2190  Resale         5
# 2   816   3800000  Whitefield  Super built-up  Area  1019  Resale         1
# 3  2708  10500000  Ambalipura  Super built-up  Area  1857  Resale        15
# 4  1041  11500000   Yelahanka  Super built-up  Area  2190  Resale         5
#
#    floor  totalFloor  bhk
# 0      1           4    1
# 1      3           5    3
# 2      2           5    2
# 3      4           5    4
# 4      3           5    3

# %%
df['bhk']>2

#Checking the condition for a column --->>> df["column_name"]condition
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 3495    False
# 3496    False
# 3497    False
# 3498    False
# 3499    False
# Name: bhk, Length: 3500, dtype: bool

# %%
df[df['bhk']>2]

#Accesing of entire rows with the condition for particular column

# df[df['column_name']condition]
# Out:
#         Id     price                     place                 built  sqft  \
# 1     2126  11500000                 Yelahanka  Super built-up  Area  2190
# 3     2708  10500000                Ambalipura  Super built-up  Area  1857
# 4     1041  11500000                 Yelahanka  Super built-up  Area  2190
# 5     2783  15000000       Devarabeesana Halli  Super built-up  Area  1672
# 7       88  15000000       Devarabeesana Halli  Super built-up  Area  1672
# ...    ...       ...                       ...                   ...   ...
# 3489  2785   4025000  Electronics City Phase 1  Super built-up  Area  1543
# 3491  1629  10500000                Ambalipura  Super built-up  Area  1857
# 3492   227  10500000                Ambalipura  Super built-up  Area  1857
# 3493  1282  10500000                Ambalipura  Super built-up  Area  1857
# 3494   595  15000000       Devarabeesana Halli  Super built-up  Area  1672
#
#         sale  yearsOld  floor  totalFloor  bhk
# ...

# %% [markdown]
# *** Data Manipulation ***

# %%
#Adding of new column :


df['Interested'] = (df['bhk']>=2) & ( df['floor']<=2)
df
# Out:
#         Id     price                 place                 built  sqft  \
# 0     1341   6300000            BTM Layout  Super built-up  Area  1450
# 1     2126  11500000             Yelahanka  Super built-up  Area  2190
# 2      816   3800000            Whitefield  Super built-up  Area  1019
# 3     2708  10500000            Ambalipura  Super built-up  Area  1857
# 4     1041  11500000             Yelahanka  Super built-up  Area  2190
# ...    ...       ...                   ...                   ...   ...
# 3495   636   3800000            Whitefield  Super built-up  Area  1019
# 3496  1664   6300000            BTM Layout  Super built-up  Area  1450
# 3497  1252   7350000        Yelachenahalli  Super built-up  Area  1330
# 3498   903   4800000  Abbaiah Reddy Layout        Built-up  Area  1200
# 3499  2183   3800000            Whitefield  Super built-up  Area  1019
#
#         sale  yearsOld  floor  totalFloor  bhk  Interested
# ...

# %%
df['address'] = df['price'] + df['place']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# ...

# %% [markdown]
# We are getting errors in the above case, this is because we are trying to add 2 different data types. Which is not possible.

# %%
df['address'] = df['place'] + " "+df['built']
df
# Out:
#         Id     price                 place                 built  sqft  \
# 0     1341   6300000            BTM Layout  Super built-up  Area  1450
# 1     2126  11500000             Yelahanka  Super built-up  Area  2190
# 2      816   3800000            Whitefield  Super built-up  Area  1019
# 3     2708  10500000            Ambalipura  Super built-up  Area  1857
# 4     1041  11500000             Yelahanka  Super built-up  Area  2190
# ...    ...       ...                   ...                   ...   ...
# 3495   636   3800000            Whitefield  Super built-up  Area  1019
# 3496  1664   6300000            BTM Layout  Super built-up  Area  1450
# 3497  1252   7350000        Yelachenahalli  Super built-up  Area  1330
# 3498   903   4800000  Abbaiah Reddy Layout        Built-up  Area  1200
# 3499  2183   3800000            Whitefield  Super built-up  Area  1019
#
#         sale  yearsOld  floor  totalFloor  bhk  Interested  \
# ...

# %%
df['condition'] = df['sale'] +" " + df['place']
df
# Out:
#         Id     price                 place                 built  sqft  \
# 0     1341   6300000            BTM Layout  Super built-up  Area  1450
# 1     2126  11500000             Yelahanka  Super built-up  Area  2190
# 2      816   3800000            Whitefield  Super built-up  Area  1019
# 3     2708  10500000            Ambalipura  Super built-up  Area  1857
# 4     1041  11500000             Yelahanka  Super built-up  Area  2190
# ...    ...       ...                   ...                   ...   ...
# 3495   636   3800000            Whitefield  Super built-up  Area  1019
# 3496  1664   6300000            BTM Layout  Super built-up  Area  1450
# 3497  1252   7350000        Yelachenahalli  Super built-up  Area  1330
# 3498   903   4800000  Abbaiah Reddy Layout        Built-up  Area  1200
# 3499  2183   3800000            Whitefield  Super built-up  Area  1019
#
#         sale  yearsOld  floor  totalFloor  bhk  Interested  \
# ...

# %%
df.dtypes
# Out:
# Id             int64
# price          int64
# place         object
# built         object
# sqft           int64
# sale          object
# yearsOld       int64
# floor          int64
# totalFloor     int64
# bhk            int64
# Interested      bool
# address       object
# condition     object
# dtype: object

# %% [markdown]
# We can find that two different columns are added

# %%
# Now we ae deleting the newly added columns

df = df.drop(['address','condition'],axis=1)
df
# Out:
#         Id     price                 place                 built  sqft  \
# 0     1341   6300000            BTM Layout  Super built-up  Area  1450
# 1     2126  11500000             Yelahanka  Super built-up  Area  2190
# 2      816   3800000            Whitefield  Super built-up  Area  1019
# 3     2708  10500000            Ambalipura  Super built-up  Area  1857
# 4     1041  11500000             Yelahanka  Super built-up  Area  2190
# ...    ...       ...                   ...                   ...   ...
# 3495   636   3800000            Whitefield  Super built-up  Area  1019
# 3496  1664   6300000            BTM Layout  Super built-up  Area  1450
# 3497  1252   7350000        Yelachenahalli  Super built-up  Area  1330
# 3498   903   4800000  Abbaiah Reddy Layout        Built-up  Area  1200
# 3499  2183   3800000            Whitefield  Super built-up  Area  1019
#
#         sale  yearsOld  floor  totalFloor  bhk  Interested
# ...

# %%
df.columns
# Out:
# Index(['Id', 'price', 'place', 'built', 'sqft', 'sale', 'yearsOld', 'floor',
#        'totalFloor', 'bhk', 'Interested'],
#       dtype='object')

# %%
df.shape
# Out:
# (3500, 11)

# %%
#Renaming of the columns

df = df.rename(columns={'Interested':'willing to buy'})

# %%
df
# Out:
#         Id     price                 place                 built  sqft  \
# 0     1341   6300000            BTM Layout  Super built-up  Area  1450
# 1     2126  11500000             Yelahanka  Super built-up  Area  2190
# 2      816   3800000            Whitefield  Super built-up  Area  1019
# 3     2708  10500000            Ambalipura  Super built-up  Area  1857
# 4     1041  11500000             Yelahanka  Super built-up  Area  2190
# ...    ...       ...                   ...                   ...   ...
# 3495   636   3800000            Whitefield  Super built-up  Area  1019
# 3496  1664   6300000            BTM Layout  Super built-up  Area  1450
# 3497  1252   7350000        Yelachenahalli  Super built-up  Area  1330
# 3498   903   4800000  Abbaiah Reddy Layout        Built-up  Area  1200
# 3499  2183   3800000            Whitefield  Super built-up  Area  1019
#
#         sale  yearsOld  floor  totalFloor  bhk  willing to buy
# ...

# %%
df['willing to buy'][0:4]
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: willing to buy, dtype: bool
